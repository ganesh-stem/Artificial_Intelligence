# %% [markdown]
# Bayesian Network: Data structure that represents the dependencies among randon variables.
#
# For example, if it's rainy today, then the flights might get delayed or ger cancelled.
# > - It uses Directed Graph.<br>
# > - Each node represents a random variable.<br>
# > - Arrow from X to Y means X is parent of Y.<br>
# > - Each node X has probability distribution P(X | Parents(X)).

# %% [markdown]
# # Approximate Inference: Sampling
# Sampling each of the nodes in the bayesian network according to their probability distribution.

# %%
# !pip install pomegranate==0.14.0
# Out:
# Collecting pomegranate==0.14.0
#   Downloading https://files.pythonhosted.org/packages/c9/c7/d627160f2c5f64345091ab666a2613c0adffd06885f5cc5902b106a62902/pomegranate-0.14.0-cp36-cp36m-manylinux2010_x86_64.whl (17.9MB)
#      |████████████████████████████████| 17.9MB 242kB/s
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate==0.14.0) (1.4.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate==0.14.0) (2.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from pomegranate==0.14.0) (3.13)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from pomegranate==0.14.0) (1.19.5)
# Requirement already satisfied: joblib>=0.9.0b4 in /usr/local/lib/python3.6/dist-packages (from pomegranate==0.14.0) (1.0.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->pomegranate==0.14.0) (4.4.2)
# Installing collected packages: pomegranate
# Successfully installed pomegranate-0.14.0

# %%
import pomegranate
from collections import Counter
from model import model

# %%
def generate_sample():

    # Mapping of random variable name to sample generated
    sample = {}

    # Mapping of distribution to sample generated
    parents = {}

    # Loop over all states, assuming topological order
    for state in model.states:

        # If we have a non-root node, sample conditional on parents
        if isinstance(state.distribution, pomegranate.ConditionalProbabilityTable):
            sample[state.name] = state.distribution.sample(parent_values=parents)

        # Otherwise, just sample from the distribution alone
        else:
            sample[state.name] = state.distribution.sample()

        # Keep track of the sampled value in the parents mapping
        parents[state.distribution] = sample[state.name]

    # Return generated sample
    return sample

# %%
# Rejection sampling
# Compute distribution of Appointment given that train is delayed
N = 10000
data = []
for i in range(N):
    sample = generate_sample()
    if sample["train"] == "delayed":
        data.append(sample["appointment"])
print(Counter(data))
# Out:
# Counter({'attend': 1239, 'miss': 863})

# %%
# Due to ramdomization, we get different values every time.
# Compute distribution of Appointment given that train is delayed
N = 10000
data = []
for i in range(N):
    sample = generate_sample()
    if sample["train"] == "delayed":
        data.append(sample["appointment"])
print(Counter(data))
# Out:
# Counter({'attend': 1276, 'miss': 834})
